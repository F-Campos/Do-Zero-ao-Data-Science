# %% [markdown]
# # Respondendo perguntas de negócio do Modulo 2

# %% [markdown]
# # 1. Crie uma nova coluna chamada: “house_age”.
#     * Se o valor da coluna “date” for maior que 2014-01-01 => ‘new_house’
#     * Se o valor da coluna “date” for menor que 2014-01-01 => ‘old_house’.

# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/kc_house_data.csv')
print( data.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Criando a coluna  “house_age” no dataset

data['fabiano'] = "house_age"
print( data.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'fabiano'],
#       dtype='object')

# %%
data.head(7)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# ...

# %%
data.loc[data['date'] > '2014-01-01', 'fabiano'] = 'new_house' 
data.loc[data['date'] < '2014-01-01', 'fabiano'] = 'old_house'

# %%
data.head(7)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# ...

# %% [markdown]
# # 2. Crie uma nova coluna chamada “dormitory_type”.
#     * Se o valor da coluna “bedrooms” for igual à 1 => ‘studio’
#     * Se o valor da coluna “bedrooms” for igual a 2 => ‘apartament’
#     * Se o valor da coluna “bedrooms” for maior que 2 => ‘house’.

# %%
# Criando a coluna  “dormitory_type” no dataset
data['dormitory'] = "dormitory_type"
print( data.columns)
data.head(7)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'fabiano', 'dormitory'],
#       dtype='object')
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
# ...

# %%
data.loc[data['bedrooms'] == 1, 'dormitory'] = 'studio' 
data.loc[data['bedrooms'] == 2, 'dormitory'] = 'apartament' 
data.loc[data['bedrooms'] > 2,'dormitory'] = 'house'

data.head(7)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# ...

# %%
# Outra forma de resolver:

# Estrategia:
# 1. Criar uma coluna nova, preenchida com NA
# 2. Percorrer todas as linhas do conjunto de dados. Para cada linha, comparar a coluna "bedrooms"
# 3. De acordo com a comparação, substituir o NA pelo dado valor


data['dormitory_type'] = 'NA'
for i in range( len( data ) ):
    if data.loc[i, 'bedrooms'] == 1:
        data.loc[i, 'dormitory_type'] = 'studio'
        
    elif data.loc[i, 'bedrooms'] == 2:
        data.loc[i, 'dormitory_type'] = 'apartment'
        
    elif data.loc[i, 'bedrooms'] > 2:
        data.loc[i, 'dormitory_type'] = 'house'

# %%
data.head(7)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# ...

# %% [markdown]
# # 3. Crie uma nova coluna chamada “condition_type”
#     * Se o valor da coluna “condition” for menor ou igual à 2 => ‘bad’
#     * Se o valor da coluna “condition” for igual à 3 ou 4 => ‘regular’
#     * Se o valor da coluna “condition” for igual à 5 => ‘good’.

# %%
data['condition'] = data['condition'].astype( int )

data['conditional_type'] = data['condition'].apply( lambda x: 'bad' if x <= 2
else 'regular' if (x == 3) | (x == 4) else 'good' )



                                                             
                                                 
                                                 
                                                 
                                                                                            
data.head(7)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode      lat  \
# 0      5650     1.0           0     0  ...             0    98178  47.5112
# 1      7242     2.0           0     0  ...          1991    98125  47.7210
# 2     10000     1.0           0     0  ...             0    98028  47.7379
# ...

# %% [markdown]
# # 4. Modifique o TIPO a Coluna “condition” para STRING.

# %%
# VErificando o tipo de variável das colunas 'id' e 'condition'

data[['id', 'condition']].dtypes
# Out:
# id           int64
# condition    int32
# dtype: object

# %%
# Modificando de int64 para String(object):

data['condition'] = data['condition'].astype( str )

# Verificando a mudança:

data[['id', 'condition']].dtypes
# Out:
# id            int64
# condition    object
# dtype: object

# %% [markdown]
# # 5. Delete as colunas: “sqft_living15” e “sqft_lot15”

# %%
print( data.columns ) 

# criando uma lista com as colunas que quero deletar:
cols = ['sqft_living15' , 'sqft_lot15']

# quando deletamos é preciso especificar o sentido do 'delete', se é no sentido das linhas ou no sentido das colunas:
data = data.drop( cols, axis = 1 )

print( data.columns )
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'fabiano', 'dormitory',
#        'dormitory_type', 'conditional_type'],
#       dtype='object')
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'fabiano', 'dormitory', 'dormitory_type',
#        'conditional_type'],
#       dtype='object')

# %% [markdown]
# # 6. Modifique o TIPO a Coluna “yr_build” para DATE

# %%
# Verificando qual o tipo de variável da coluna "yr_built"

data[['yr_built']].dtypes
# Out:
# yr_built    int64
# dtype: object

# %%
# Modificando para "Date"
data['yr_built'] = pd.to_datetime( data['yr_built'], format= '%Y' )

# Verificando a mudança:
pd.to_datetime( data['yr_built'], format= '%Y' )
# Out:
# 0       1955-01-01
# 1       1951-01-01
# 2       1933-01-01
# 3       1965-01-01
# 4       1987-01-01
#            ...
# 21608   2009-01-01
# 21609   2014-01-01
# 21610   2009-01-01
# 21611   2004-01-01
# 21612   2008-01-01
# Name: yr_built, Length: 21613, dtype: datetime64[ns]

# %% [markdown]
# # 7. Modifique o TIPO a Coluna “yr_renovated” para DATE

# %%
data['yr_renovated']


# # Modificando para "Date"
# data['yr_renovated'] = pd.to_datetime( data['yr_built'], format= '%Y' )

# # Verificando a mudança:
# pd.to_datetime( data['yr_renovated'], format= '%Y' )
# Out:
# 0           0
# 1        1991
# 2           0
# 3           0
# 4           0
#          ...
# 21608       0
# 21609       0
# 21610       0
# 21611       0
# 21612       0
# Name: yr_renovated, Length: 21613, dtype: int64

# %%
data['yr_renovated'] = data['yr_renovated'].apply( lambda x: pd.to_datetime( '1900-01-01', format='%Y-%m-%d' ) if x==0 else pd.to_datetime( x,format='%Y'))

# %%
data.dtypes
# Out:
# id                           int64
# date                        object
# price                      float64
# bedrooms                     int64
# bathrooms                  float64
# sqft_living                  int64
# sqft_lot                     int64
# floors                     float64
# waterfront                   int64
# view                         int64
# condition                   object
# grade                        int64
# sqft_above                   int64
# sqft_basement                int64
# yr_built            datetime64[ns]
# yr_renovated        datetime64[ns]
# zipcode                      int64
# lat                        float64
# long                       float64
# fabiano                     object
# dormitory                   object
# dormitory_type              object
# conditional_type            object
# dtype: object

# %% [markdown]
# # 8. Qual a data mais antiga de construção de um imóvel?

# %%
min_date = data['yr_built'].min()

print( 'The oldest house is {} years old'.format( min_date ) )
# Out:
# The oldest house is 1900-01-01 00:00:00 years old

# %% [markdown]
# # 9. Qual a data mais antiga de renovação de um imóvel?

# %%
# Estrategia
# 1. Filtrar todas as linhas diferentes de ZERO ( imóveis que nao foram reformados )
# 2. Encontrar a data mínima

data.loc[data['yr_renovated'] > pd.to_datetime('1900-01-01', format='%Y-%m-%d'), 'yr_renovated'].min()
# Out:
# Timestamp('1934-01-01 00:00:00')

# %% [markdown]
# # 10. Quantos imóveis tem 2 andares?

# %%
# Estrategia:
# 1. Filtrar todoso os imóveis com 2 andares
# 2. Contar o número de linhas

houses = data.loc[data['floors'] == 2, 'id'].size

print( 'Number of Houses in "regular" condition is: {}'.format( houses ) )
# Out:
# Number of Houses in "regular" condition is: 8241

# %% [markdown]
# # 11. Quantos imóveis estão com a condição igual a “regular” ?

# %%
# Estrategia
# 1. Filtrar todos os apartamentos com "condition_type" igual a "regular"
# 2. Contar o número de imóveis sob essa condição

data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'fabiano', 'dormitory', 'dormitory_type',
#        'conditional_type'],
#       dtype='object')

# %%
data.loc[data['conditional_type'] == 'regular', 'id' ].size
# Out:
# 19710

# %% [markdown]
# # 12. Quantos imóveis estão com a condição igual a “bad”e possuem “vista para água” ?

# %%
# Estrategia:
# 1. Filtrar as colunas "conditional_type" igual a "bad" e "waterfront" igual a 1
# 2. Contar o número de linhas

data.loc[( data['conditional_type'] == 'bad') & (data['waterfront'] == 1), "id"].size
# Out:
# 2

# %% [markdown]
# # 13. Quantos imóveis estão com a condição igual a “good” e são “new_house”?

# %%
# Estrategia:
# 1. Filtrar as colunas "conditional_type" igual a "good" e "house_age" igual "new_house"
# 2. Contar o número de linhas

data.loc[( data['conditional_type'] == 'good') & ( data['fabiano'] == 'new_house'), 'id'].size
# Out:
# 1701

# %% [markdown]
# # 14. Qual o valor do imóvel mais caro do tipo “studio” ?

# %%
# Estrategia:
# 1. Filtrar as colunas "dormitory_type" igual a "studio"
# 2. Encontrar o máximo valor da coluna "price"


data.loc[data['dormitory_type'] == 'studio', 'price'].max()
# Out:
# 1247000.0

# %% [markdown]
# # 15. Quantos imóveis do tipo “apartment” foram reformados em 2015 ?

# %%
# Estrategia:
# 1. Filtrar as colunas "dormitory_type" igual a "apartament" e "yr_renovated" igual a "2015-01-01"
# 2. Contar o número de linhas'

data.loc[(data['dormitory_type']=='apartament') & (data['yr_renovated']=='2015'), 'id'].size
# Out:
# 0

# %% [markdown]
# # 16. Qual o maior número de quartos que um imóveis do tipo “house” possui ?

# %%
# Estrategia:
# 1. Filtrar as colunas "dormitory type" igual a "house"
# 2. Encontrar o maior valor da coluna bedrooms


data.loc[data['dormitory_type'] == 'house', 'bedrooms'].max()
# Out:
# 33

# %% [markdown]
# # 17. Quantos imóveis “new_house” foram reformados no ano de 2014?

# %%
# Estrategia:
# 1. Filtrar as colunas "dormitory_type" igual a "apartament" e "yr_renovated" igual "2015-01-01"
# 2. Contar o número de linhas

data.loc[( data['fabiano'] == 'new_house' ) & 
         ( data['yr_renovated'] == pd.to_datetime('2014-01-01', format = '%Y-%m-%d')), 'id'].size
# Out:
# 91

# %% [markdown]
# # 18. Selecione as colunas: “id”, “date”, “price”, “floors”, “zipcode” pelo método:
#     * Direto pelo nome das colunas
#     * Pelos índices
#     * Pelos índices das linhas e o nome das colunas
#     * Índices Booleanos

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'fabiano', 'dormitory', 'dormitory_type',
#        'conditional_type'],
#       dtype='object')

# %%
# 1. Nome das colunas
data[['id', 'date', 'price', 'floors', 'zipcode']]

# 2. Índices
data.iloc[:, [0, 1, 2, 7, 16]]

# 3. Índices das linhas e nome das colunas
data.loc[:, ['id', 'date', 'price', 'floors', 'zipcode']]

# Índices Booleanos
data.iloc[0:10, [] ]

i = [True, True, True, False, False, False,
       False, True, False, False, False, False,
       False, False, False, False, True,
       False, False, False, False, False,
       False]
data.iloc[0:10, i]
# Out:
#            id             date      price  floors  zipcode
# 0  7129300520  20141013T000000   221900.0     1.0    98178
# 1  6414100192  20141209T000000   538000.0     2.0    98125
# 2  5631500400  20150225T000000   180000.0     1.0    98028
# 3  2487200875  20141209T000000   604000.0     1.0    98136
# 4  1954400510  20150218T000000   510000.0     1.0    98074
# 5  7237550310  20140512T000000  1225000.0     1.0    98053
# 6  1321400060  20140627T000000   257500.0     2.0    98003
# 7  2008000270  20150115T000000   291850.0     1.0    98198
# 8  2414600126  20150415T000000   229500.0     1.0    98146
# 9  3793500160  20150312T000000   323000.0     2.0    98038

# %% [markdown]
# # 19. Salve um arquivo .csv com somente as colunas do item 10 ao 17.

# %%
data[['fabiano', 'dormitory_type', 'conditional_type']].to_csv( 'exercicio_19.csv' )
